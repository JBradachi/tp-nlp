# %%
import pandas as pd

# %%
ds = pd.read_csv("caracteristicas.csv")
ds
# Out:
#                 id          date_created catalog_product_id  \
# 0      MLB46241561  2025-02-21T13:14:52Z        MLB46241561
# 1      MLB39940858  2024-08-27T21:56:42Z        MLB39940858
# 2      MLB48776606  2025-04-19T02:23:06Z        MLB48776606
# 3      MLB59018447  2025-10-05T02:13:07Z        MLB59018447
# 4      MLB44743999  2024-12-13T15:48:20Z        MLB44743999
# ...            ...                   ...                ...
# 24289  MLB49394953  2025-05-10T17:41:29Z        MLB49394953
# 24290  MLB49423837  2025-05-10T19:54:05Z        MLB49423837
# 24291  MLB49255389  2025-05-10T03:55:08Z        MLB49255389
# 24292  MLB50091398  2025-05-16T07:25:43Z        MLB50091398
# 24293  MLB49654667  2025-05-12T11:34:44Z        MLB49654667
#
#                                   domain_id  \
# 0      MLB-REFRIGERATOR_AND_FREEZER_SENSORS
# 1      MLB-REFRIGERATOR_AND_FREEZER_SENSORS
# 2      MLB-REFRIGERATOR_AND_FREEZER_SENSORS
# 3      MLB-REFRIGERATOR_AND_FREEZER_SENSORS
# ...

# %%
ds2 = pd.read_csv("contexto.csv")
ds2
# Out:
#                  Context_Id              Context    value_id  \
# 0                     BRAND                Marca       188.0
# 1                     MODEL               Modelo  47713338.0
# 2               SENSOR_TYPE       Tipo de sensor  39861884.0
# 3                    WEIGHT                 Peso  19173692.0
# 4                     BRAND                Marca  17452295.0
# ...                     ...                  ...         ...
# 313939                WIDTH              Largura   7800080.0
# 313940               LENGTH          Comprimento   7816567.0
# 313941  WITH_REMOTE_CONTROL  Com controle remoto    242085.0
# 313942           WITH_WI_FI            Com Wi-Fi    242085.0
# 313943         MANUFACTURER           Fabricante   1180954.0
#
#                      value_name           id
# 0                    Electrolux  MLB46241561
# 1       YI09F YI09R YI12F YI12R  MLB46241561
# 2                   Temperatura  MLB46241561
# 3                         0.2 g  MLB46241561
# ...

# %%
ds3 = pd.read_csv("perguntas.csv")
ds3
# Out:
#                                                 pergunta  \
# 0      Minha cervejeira é VN28AF Termostato sollatek ...
# 1                        Esse termostato tem os 4 pinos?
# 2                        Teria para o modelo VF56DB 220V
# 3                                          Ok ele e 220v
# 4        Bom dia ele serve para o modelo vb15 metal frio
# ...                                                  ...
# 57041                                   Olá é luz quente
# 57042            Precisso da nota fiscal de este produto
# 57043  Muito obrigado pela atenção, E27 que preciso. ...
# 57044       Comprei chegou mas a rosca não é E27 é menor
# 57045                                 tem branco quente?
#
#                                                 resposta           id  \
# 0      Boa tarde, seu termostato saiu de linha o subs...  MLB44743999
# 1      Boa tarde, são 6 pinos porem os que tem função...  MLB44743999
# ...

# %%
ds3 = pd.read_csv("avaliacoes.csv")
ds3
# Out:
#                                                    texto nota           id  \
# 0                                   Excelente produto!!.    5  MLB46241561
# 1                                             Muito bom.    5  MLB48090512
# 2                                     Muito bom produto.    5  MLB48090512
# 3                              Produto bom. Sem retorno.    5  MLB48090512
# 4      Produto confiável e original. Eu mesmo arrumei...    5  MLB29176649
# ...                                                  ...  ...          ...
# 18069  Funcional , porém não segura bateria tem q fic...    4  MLB37428293
# 18070                                            Gostei.    5  MLB37428293
# 18071  O altofalante é elogiado por seu design atraen...    5  MLB37428293
# 18072  Não gostei pois na discrição fala que funciona...    2  MLB37428293
# 18073                                   Amazon é amazon.    5  MLB43328724
#
#                data
# 0      09 out. 2025
# 1      15 out. 2025
# ...
